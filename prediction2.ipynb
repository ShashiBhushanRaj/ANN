# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model

# %%
## load the IMDB dataset word index
word_index=imdb.get_word_index()
reverse_wrod_index={value:key for key,value in word_index.items()}

# %%
## load the pre_trained model with relu activation funciton
model=load_model('simple_rnn_imdb.h5')
model.summary()
# Out:
# WARNING:tensorflow:From d:\DeepLearning\venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 128)          1280000
#
#  simple_rnn (SimpleRNN)      (None, 128)               32896
#
#  dense (Dense)               (None, 1)                 129
#
# =================================================================
# Total params: 1313025 (5.01 MB)
# Trainable params: 1313025 (5.01 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[-0.0370925 , -0.03184562,  0.01453549, ..., -0.03930083,
#          -0.00439144, -0.01757666],
#         [-0.04447468,  0.04911093,  0.03349248, ...,  0.07112504,
#           0.03899757, -0.02458178],
#         [-0.06040484, -0.0585496 , -0.02238299, ...,  0.05237322,
#          -0.06479527, -0.04522439],
#         ...,
#         [ 0.05175012,  0.08334479, -0.00748382, ..., -0.09785149,
#           0.02814242,  0.08716844],
#         [ 0.0029835 ,  0.06152141,  0.01548016, ...,  0.0307577 ,
#          -0.029409  ,  0.0149406 ],
#         [-0.00863037,  0.03734745, -0.03669387, ..., -0.0107098 ,
#          -0.00633452,  0.01713051]], dtype=float32),
#  array([[ 0.1640944 , -0.07775536, -0.0137961 , ..., -0.10465129,
#           0.10352768, -0.07695566],
#         [ 0.1266768 , -0.17044066, -0.00357174, ..., -0.07649733,
#          -0.14046542, -0.0568975 ],
#         [ 0.10966685,  0.02039167, -0.1180606 , ..., -0.17125975,
#           0.01390644,  0.08961093],
#         ...,
#         [ 0.19235031,  0.00041169,  0.07164814, ...,  0.15195939,
#          -0.08715909,  0.10004965],
#         [ 0.14424957, -0.05366058,  0.1357124 , ..., -0.16137809,
#          -0.15819491,  0.00938716],
#         [ 0.09311858, -0.04372803, -0.0895742 , ...,  0.14745599,
#           0.07565561, -0.17279324]], dtype=float32),
#  array([[-0.18920359, -0.02718898, -0.10195265, ...,  0.04321029,
#          -0.04065008,  0.2772306 ],
#         [-0.01249464,  0.02527199,  0.02781554, ...,  0.10102855,
#          -0.07503912,  0.06252588],
#         [ 0.19665867, -0.00502781,  0.11391298, ...,  0.05679208,
#           0.06241963,  0.01903945],
#         ...,
#         [-0.0096491 , -0.10377849, -0.02603598, ...,  0.0999852 ,
#          -0.06863111,  0.02423103],
#         [ 0.01219198, -0.04602724,  0.05671557, ...,  0.20977408,
#           0.01574874, -0.09880519],
#         [-0.02001365, -0.04072192, -0.03205443, ..., -0.01151152,
#           0.16682042, -0.04838327]], dtype=float32),
#  array([ 0.02052372, -0.02420432, -0.03469845, -0.02573668,  0.0080993 ,
#          0.05305493, -0.02960609, -0.02985426,  0.01655797, -0.00136225,
#         -0.03915158,  0.02017543, -0.02137203,  0.02255228, -0.0266285 ,
#         -0.01874303, -0.02482728,  0.01304347, -0.03139118, -0.04260082,
#         -0.03885341, -0.02344632, -0.06824785, -0.02535248, -0.02762909,
#         -0.02551195, -0.02063619,  0.03171707,  0.04350801,  0.02796843,
#         -0.02526857, -0.04283341,  0.01228728,  0.03758287, -0.04646615,
#          0.03041427,  0.02639108, -0.00407463,  0.05292067, -0.02185524,
#          0.07124068,  0.02912118, -0.01652291, -0.02332566,  0.01089686,
#          0.05062661,  0.00585438, -0.03689811, -0.04776112,  0.01424969,
#         -0.00789147,  0.02403804, -0.02495209, -0.00161964,  0.00738542,
#         -0.00424531,  0.03948772, -0.01034511,  0.05192713,  0.00494251,
#          0.02200193,  0.00317116, -0.05060321, -0.03937286,  0.0553499 ,
#          0.0115635 ,  0.03781095, -0.03399695, -0.03451123, -0.04457958,
#         -0.03228884,  0.00903555, -0.05933474,  0.05379554, -0.04423846,
#         -0.01711264,  0.04133923, -0.03540738, -0.04816092,  0.01834108,
#         -0.04918795, -0.00256396,  0.01412452, -0.04926939, -0.01476357,
#          0.04953622,  0.01765414,  0.04171533, -0.0620892 , -0.03792559,
#          0.02801201, -0.0425697 , -0.07028724, -0.01423233,  0.0029512 ,
#         -0.05517936,  0.04418533, -0.03838885,  0.01046101,  0.02946093,
#          0.00391696,  0.02395542,  0.0699592 , -0.02821567, -0.02133871,
#         -0.01833786, -0.01275515,  0.02095402,  0.04119014, -0.00792949,
#         -0.0265172 , -0.0012491 , -0.02324131, -0.04611193, -0.04899225,
#         -0.02790721, -0.01980658,  0.04289256, -0.05081336, -0.01207992,
#          0.01898327, -0.02349947, -0.01266776,  0.02255716, -0.00292877,
#         -0.0315443 , -0.01866375, -0.05568905], dtype=float32),
#  array([[-0.13634472],
#         [ 0.1218914 ],
#         [ 0.02297164],
#         [ 0.07298371],
#         [ 0.4729953 ],
#         [ 0.1703162 ],
#         [-0.04255811],
#         [ 0.40109578],
#         [ 0.20462653],
#         [ 0.21109915],
#         [ 0.01956191],
#         [ 0.14907114],
#         [ 0.23369165],
#         [-0.05411268],
#         [ 0.49160537],
#         [ 0.19011275],
#         [ 0.00825419],
#         [-0.15770486],
#         [ 0.12055172],
#         [-0.328792  ],
#         [-0.05375953],
#         [-0.0796722 ],
#         [-0.08897808],
#         [ 0.0624439 ],
#         [ 0.07935402],
#         [ 0.19078234],
#         [-0.00853746],
#         [ 0.10667612],
#         [-0.10797533],
#         [ 0.08938611],
#         [-0.3130081 ],
#         [ 0.21173605],
#         [-0.25633025],
#         [-0.152972  ],
#         [-0.02321259],
#         [ 0.06668618],
#         [-0.06654578],
#         [-0.00344659],
#         [ 0.01304811],
#         [ 0.16100617],
#         [ 0.19817734],
#         [-0.14050981],
#         [-0.15274425],
#         [-0.08097175],
#         [-0.171146  ],
#         [-0.04868634],
#         [ 0.14822969],
#         [-0.06175246],
#         [-0.08031593],
#         [ 0.02432607],
#         [ 0.18296672],
#         [-0.06772227],
#         [ 0.1441075 ],
#         [-0.18473735],
#         [-0.17745633],
#         [ 0.41358325],
#         [-0.13504103],
#         [ 0.08999679],
#         [-0.12533183],
#         [-0.04826626],
#         [ 0.06755426],
#         [ 0.01959667],
#         [ 0.06987803],
#         [ 0.10032913],
#         [-0.05708569],
#         [-0.06190606],
#         [-0.05350394],
#         [-0.03760066],
#         [ 0.06845109],
#         [ 0.07486872],
#         [ 0.285241  ],
#         [ 0.15491055],
#         [ 0.0582997 ],
#         [-0.02326526],
#         [ 0.152348  ],
#         [ 0.4782353 ],
#         [ 0.21590857],
#         [ 0.06781112],
#         [ 0.17162365],
#         [-0.1795147 ],
#         [ 0.04598802],
#         [ 0.19819847],
#         [-0.47928253],
#         [ 0.16196583],
#         [-0.12905905],
#         [-0.02611686],
#         [-0.07613857],
#         [ 0.01625551],
#         [ 0.02153927],
#         [-0.19132602],
#         [-0.00473069],
#         [ 0.29579446],
#         [ 0.09231075],
#         [ 0.0394828 ],
#         [ 0.2298714 ],
#         [ 0.08435838],
#         [ 0.00068461],
#         [-0.18304275],
#         [ 0.014793  ],
#         [-0.22275645],
#         [ 0.1550422 ],
#         [-0.55077165],
#         [-0.04831439],
#         [-0.07621945],
#         [-0.30275992],
#         [ 0.00328355],
#         [-0.18094599],
#         [ 0.00473073],
#         [-0.17702791],
#         [-0.35287756],
#         [ 0.22803807],
#         [ 0.03012252],
#         [ 0.12623225],
#         [ 0.04939858],
#         [ 0.19393437],
#         [ 0.09129433],
#         [ 0.5630798 ],
#         [-0.02294468],
#         [ 0.29103228],
#         [ 0.24717596],
#         [-0.14096786],
#         [ 0.19245954],
#         [ 0.17870769],
#         [-0.21700981],
#         [-0.1354845 ],
#         [ 0.10435015],
#         [ 0.48396662],
#         [ 0.2196053 ]], dtype=float32),
#  array([0.582496], dtype=float32)]

# %%
## step 2:helper functions
## function to decode reviews 

def decode_review(encoded_review):
    return ' '.join([reverse_word_index.get(i-3,'?') for i in encoded_review])


# function to preprocesses user input
def preprocess_text(text):
    words=text.lower().split()
    encoded_review=[word_index.get(word,2) + 3 for word in words]
    padded_review=sequence.pad_sequences([encoded_review],maxlen=500)
    return padded_review

# %%
### prediction function

def predict_sentiment(review):
    preprocessed_input=preprocess_text(review)
    
    prediction=model.predict(preprocessed_input)
    
    sentiment='Positive' if prediction[0][0] >0.5 else 'Negative'
    
    return sentiment,prediction[0][0]

# %%
### example
example_review="this movie was fantastic! the acting was great and the plot was thrilling"

# %%
sentiment,score=predict_sentiment(example_review)

print(f'review {example_review}')
print(f'sentiment: {sentiment}')
print(f'prediction score:{score}')
# Out:
# 1/1 [==============================] - 0s 30ms/step
# review this movie was fantastic! the acting was great and the plot was thrilling
# sentiment: Negative
# prediction score:0.2392195463180542
